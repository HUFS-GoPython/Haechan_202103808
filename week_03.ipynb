# %% [markdown]
# ## 논리연산자
# - 비교연산자가 여러 번 사용될 때 사용
# - 종류
#     - `(A) and (B)`: A도 참이고, B도 참일 때 True
#     - `(A) or (B)`: A나 B, 둘 중 하나만 참이어도 True
#     - `not (A)`: A의 반대의 논리값
# - 비교연산자를 이용한 식에서 괄호는 가독성을 높임 (optional)

# %% [markdown]
# ## 중첩조건문
# - nested conditional
# - if 실행 코드 부분에 또다른 if
# - 들여쓰기 주의하기

# %% [markdown]
# ### 중첩조건문 피하기
# - 중첩조건문은 복잡해지기 쉽기 때문에 가능한 피하는 것이 좋음
# - 논리연산자(and, or 등) 사용
# - 부등호 사이에 넣기

# %%
# 중첩조건문 1
x = 0
y = 1

if x == y:
    print("Block A")
else:
    if x < y:
        print("Block B")
    else:
        print("Block C")

# 단순조건문으로 수정
x = 0
y = 1

if x == y:
    print("Block A")
elif x < y:
    print("Block B")
else:
    print("Block C")
# Out:
# Block B
# Block B

# %%
# 중첩조건문 2
x = 3

if x < 10:
    if 5 <= x:
        print("Block A")
    else:
        print("Block B")
else: print("Block B")

# 단순조건문으로 수정: 방법 1
x = 3

if (x >= 5) and (x < 10):
    print("Block A")
else:
    print("Block B")
    
# 단순조건문으로 수정: 방법 2
x = 3

if 5 <= x < 10:
    print("Block A")
else:
    print("Block B")
# Out:
# Block B
# Block B
# Block B

# %% [markdown]
# ### True / False
# - 만약 a가 참이라면
# --> `a = True`

# %%
a = 10

if a:
    print('True')

"""
if a == True:
    print('True')
처럼 쓰지 말기
"""
# Out:
# True
# "\nif a == True:\n    print('True')\n처럼 쓰지 말기\n"

# %% [markdown]
# ### in
# - membership operator
# - 어떤 요소가 그 안에 있는지 확인하고 싶을 때
# - 비슷한 조건이 여러 번 반복될 때

# %% [markdown]
# #### 예시: 어떤 letter가 모음인지 확인하고 싶을 때
# - 논리연산자를 사용한 코드를 `in`을 사용하여 수정해보자

# %%
# 논리연산자 사용
letter = 'k'

if letter == 'a' or letter == 'e' or letter == 'i' or letter == 'o' or letter == 'u':
    print("Yes")
else:
    print("No")

# `in` 사용
letter = 'k'

if letter in ['a', 'e', 'i', 'o', 'u']: # 리스트 요소에 letter와 일치하는 것이 있는가
    print("Yes")
else:
    print("No")
# Out:
# No
# No

# %% [markdown]
# 어떤 문자열에 모음이 있는지 확인하는 코드를 `in`을 사용하여 짜기

# %%
string_1 = 'abcd'

if ('a' or 'e' or 'i' or 'o' or 'u') in string_1:
    print("Yes")
else: print("No")
# Out:
# Yes

# %% [markdown]
# ### 바다코끼리 연산자
# - walrus operator
# - 할당과 테스트를 동시에 하는 기능
# - 길이를 줄이기 좋음
# - `:=`

# %% [markdown]
# 예시:

# %%
tweet_limit = 200
tweet_string = 'blah' * 50
tweet_string
# Out:
# 'blahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblah'

# %% [markdown]
# 바다코끼리 연산자를 쓰지 않았을 때

# %%
diff = tweet_limit - len(tweet_string)
if diff > 0:
    print("가능")
else: print("불가능")
# Out:
# 불가능

# %% [markdown]
# 바다코끼리 연산자를 썼을 때

# %%
if diff := tweet_limit - len(tweet_string) > 0:
    print("가능")
else: print("불가능")
# Out:
# 불가능

# %% [markdown]
# ### Quiz
# - 윤년을 구하는 코드를 짜보자
#     - 연도가 4로 나눠떨어지면 윤년
#     - 100으로 나눠떨어지면 안된다
#     - 400으로 나눠떨어지면 된다
# - year를 입력받는다.
# - '{}년은 윤년입니다.' / "{}년은 윤년이 아닙니다."

# %%
year = int(input('연도를 입력하세요:'))
# Out:
# 연도를 입력하세요: 4800

# %%
if (year % 4 == 0) and ((year % 100 != 0) or (year % 400 == 0)):
    print(f'{year}년은 윤년입니다.')
else: print(f'{year}년은 윤년이 아닙니다.')
# Out:
# 4800년은 윤년입니다.

# %% [markdown]
# ## String \ 문자열
# - str type
# - 시스템에서 가장 작은 단위
# - 불변적인 성격 (immutable)
#     - 'abce'가 있을 때, b를 a로 바꿀 수 없음
# - 문법: `'`이나 `"`으로 감싸기
#     - 예: '24'
# - `'''` or `"""`으로 주석 가능
# - 형 변환은 `str()`

# %% [markdown]
# ### 문자열의 연산
# - `+`: 붙이기
#     - 공백 없음
# - `*`: 복제하기

# %% [markdown]
# ### Slicing
# - 지정 범위의 문자열을 추출하는 것
# - 문법: `[offset]`
#     - `[start:end:step]`
# - 오프셋은 0부터 시작
#     - 역순일 경우 -1부터 시작
# - start는 포함(크거나 같다), end는 불포함(작다)
# - 0일 경우 생략한다
#     - ~4까지 출력 --> [:5]
#     - 처음부터 끝까지 2스텝씩 --> [::2]
#     - 처음부터 끝까지 역순 --> [::-1]

# %%
sent = 'Hello there!'
print(sent)

# 2번 글자 출력
print(sent[1])

# 3번 글자 출력(end 포함)
print(sent[3:4])

# 1번 글자부터 4번 글자까지 출력
print(sent[:4])

# 첫 글자부터 마지막 글자까지 2스텝으로 출력
print(sent[::2])

# 첫 글자부터 마지막 글자까지 역순으로 출력
print(sent[::-1])
# Out:
# Hello there!
# e
# l
# Hell
# Hlotee
# !ereht olleH

# %% [markdown]
# #### 참고: `set`과 `list`
# - `set`
#     - `{a, b, c, ...}`
#     - 중복 불가능
#     - 집합의 개념
#     - 순서 없음 -> 슬라이싱 불가
# - `list`
#     - `[a, b, c, ...]`
#     - 중복 가능
#     - 순서 있음 -> 슬라이싱 가능

# %% [markdown]
# ### length
# - 길이를 세는 함수
# - 문법: `len()`
# - 공백까지 포함

# %% [markdown]
# ## Escape character \ 이스케이프 문자
# - 눈에 보이는 대로 인식되지 않는 문자열
# - 문법: `\<character>`
# - 종류
#     - `\n`: new line
#     - `\t`: tap
#     - `\b`: back space
#     - `\'`: single quote을 문자열 그대로 인식하게 해줌
# - print 함수를 쓰지 않으면 형태가 출력은 된다.
# - `\n`을 그대로 출력하려면?
#     - \\n
#     - r'\n' (raw string: 원시 문자를 반환)
# - 문자열을 바꾸는 것이 아니라 표면 상의 형태를 바꾸는 것

# %%
sent = 'Hello world, Im Haechan.'
print(sent)

sent = 'Hello world, \nIm Haechan.'
print(sent)

sent = 'Hello world,\b Im Haechan.'
print(sent)

sent = 'Hello world, I\'m Haechan.'
print(sent)
# Out:
# Hello world, Im Haechan.
# Hello world,
# Im Haechan.
# Hello world Im Haechan.
# Hello world, I'm Haechan.

# %% [markdown]
# ## NLTK
# - Natural Language Toolkit
# - 교육용으로 개발된 자연어처리 패키지
# - 분석된 코퍼스 제공
#     - 토크나이즈, 파싱, 테깅, ...

# %%
# 설치하기
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\anaconda3\lib\site-packages (3.6.5)
# Requirement already satisfied: click in c:\anaconda3\lib\site-packages (from nltk) (8.0.3)
# Requirement already satisfied: joblib in c:\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\anaconda3\lib\site-packages (from nltk) (2021.8.3)
# Requirement already satisfied: tqdm in c:\anaconda3\lib\site-packages (from nltk) (4.62.3)
# Requirement already satisfied: colorama in c:\users\bingo\appdata\roaming\python\python39\site-packages (from click->nltk) (0.4.4)

# %%
# 가져오기
import nltk
nltk.download('book', quiet=True)
# Out:
# True

# %%
# book 가져오기
from nltk import book

# %%
# text 접근하기
moby = book.text1

# %%
# text1의 토큰에 접근하기
moby.tokens
# Out:
# ['[',
#  'Moby',
#  'Dick',
#  'by',
#  'Herman',
#  'Melville',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.',
#  '(',
#  'Supplied',
#  'by',
#  'a',
#  'Late',
#  'Consumptive',
#  'Usher',
#  'to',
#  'a',
#  'Grammar',
#  'School',
#  ')',
#  'The',
#  'pale',
#  'Usher',
#  '--',
#  'threadbare',
#  'in',
#  'coat',
#  ',',
#  'heart',
#  ',',
#  'body',
#  ',',
#  'and',
#  'brain',
#  ';',
#  'I',
#  'see',
#  'him',
#  'now',
#  '.',
#  'He',
#  'was',
#  'ever',
#  'dusting',
#  'his',
#  'old',
#  'lexicons',
#  'and',
#  'grammars',
#  ',',
#  'with',
#  'a',
#  'queer',
#  'handkerchief',
#  ',',
#  'mockingly',
#  'embellished',
#  'with',
#  'all',
#  'the',
#  'gay',
#  'flags',
#  'of',
#  'all',
#  'the',
#  'known',
#  'nations',
#  'of',
#  'the',
#  'world',
#  '.',
#  'He',
#  'loved',
#  'to',
#  'dust',
#  'his',
#  'old',
#  'grammars',
#  ';',
#  'it',
#  'somehow',
#  'mildly',
#  'reminded',
#  'him',
#  'of',
#  'his',
#  'mortality',
#  '.',
#  '"',
#  'While',
#  'you',
#  'take',
#  'in',
#  'hand',
#  'to',
#  'school',
#  'others',
#  ',',
#  'and',
#  'to',
#  'teach',
#  'them',
#  'by',
#  'what',
#  'name',
#  'a',
#  'whale',
#  '-',
#  'fish',
#  'is',
#  'to',
#  'be',
#  'called',
#  'in',
#  'our',
#  'tongue',
#  'leaving',
#  'out',
#  ',',
#  'through',
#  'ignorance',
#  ',',
#  'the',
#  'letter',
#  'H',
#  ',',
#  'which',
#  'almost',
#  'alone',
#  'maketh',
#  'the',
#  'signification',
#  'of',
#  'the',
#  'word',
#  ',',
#  'you',
#  'deliver',
#  'that',
#  'which',
#  'is',
#  'not',
#  'true',
#  '."',
#  '--',
#  'HACKLUYT',
#  '"',
#  'WHALE',
#  '.',
#  '...',
#  'Sw',
#  '.',
#  'and',
#  'Dan',
#  '.',
#  'HVAL',
#  '.',
#  'This',
#  'animal',
#  'is',
#  'named',
#  'from',
#  'roundness',
#  'or',
#  'rolling',
#  ';',
#  'for',
#  'in',
#  'Dan',
#  '.',
#  'HVALT',
#  'is',
#  'arched',
#  'or',
#  'vaulted',
#  '."',
#  '--',
#  'WEBSTER',
#  "'",
#  'S',
#  'DICTIONARY',
#  '"',
#  'WHALE',
#  '.',
#  '...',
#  'It',
#  'is',
#  'more',
#  'immediately',
#  'from',
#  'the',
#  'Dut',
#  '.',
#  'and',
#  'Ger',
#  '.',
#  'WALLEN',
#  ';',
#  'A',
#  '.',
#  'S',
#  '.',
#  'WALW',
#  '-',
#  'IAN',
#  ',',
#  'to',
#  'roll',
#  ',',
#  'to',
#  'wallow',
#  '."',
#  '--',
#  'RICHARDSON',
#  "'",
#  'S',
#  'DICTIONARY',
#  'KETOS',
#  ',',
#  'GREEK',
#  '.',
#  'CETUS',
#  ',',
#  'LATIN',
#  '.',
#  'WHOEL',
#  ',',
#  'ANGLO',
#  '-',
#  'SAXON',
#  '.',
#  'HVALT',
#  ',',
#  'DANISH',
#  '.',
#  'WAL',
#  ',',
#  'DUTCH',
#  '.',
#  'HWAL',
#  ',',
#  'SWEDISH',
#  '.',
#  'WHALE',
#  ',',
#  'ICELANDIC',
#  '.',
#  'WHALE',
#  ',',
#  'ENGLISH',
#  '.',
#  'BALEINE',
#  ',',
#  'FRENCH',
#  '.',
#  'BALLENA',
#  ',',
#  'SPANISH',
#  '.',
#  'PEKEE',
#  '-',
#  'NUEE',
#  '-',
#  'NUEE',
#  ',',
#  'FEGEE',
#  '.',
#  'PEKEE',
#  '-',
#  'NUEE',
#  '-',
#  'NUEE',
#  ',',
#  'ERROMANGOAN',
#  '.',
#  'EXTRACTS',
#  '(',
#  'Supplied',
#  'by',
#  'a',
#  'Sub',
#  '-',
#  'Sub',
#  '-',
#  'Librarian',
#  ').',
#  'It',
#  'will',
#  'be',
#  'seen',
#  'that',
#  'this',
#  'mere',
#  'painstaking',
#  'burrower',
#  'and',
#  'grub',
#  '-',
#  'worm',
#  'of',
#  'a',
#  'poor',
#  'devil',
#  'of',
#  'a',
#  'Sub',
#  '-',
#  'Sub',
#  'appears',
#  'to',
#  'have',
#  'gone',
#  'through',
#  'the',
#  'long',
#  'Vaticans',
#  'and',
#  'street',
#  '-',
#  'stalls',
#  'of',
#  'the',
#  'earth',
#  ',',
#  'picking',
#  'up',
#  'whatever',
#  'random',
#  'allusions',
#  'to',
#  'whales',
#  'he',
#  'could',
#  'anyways',
#  'find',
#  'in',
#  'any',
#  'book',
#  'whatsoever',
#  ',',
#  'sacred',
#  'or',
#  'profane',
#  '.',
#  'Therefore',
#  'you',
#  'must',
#  'not',
#  ',',
#  'in',
#  'every',
#  'case',
#  'at',
#  'least',
#  ',',
#  'take',
#  'the',
#  'higgledy',
#  '-',
#  'piggledy',
#  'whale',
#  'statements',
#  ',',
#  'however',
#  'authentic',
#  ',',
#  'in',
#  'these',
#  'extracts',
#  ',',
#  'for',
#  'veritable',
#  'gospel',
#  'cetology',
#  '.',
#  'Far',
#  'from',
#  'it',
#  '.',
#  'As',
#  'touching',
#  'the',
#  'ancient',
#  'authors',
#  'generally',
#  ',',
#  'as',
#  'well',
#  'as',
#  'the',
#  'poets',
#  'here',
#  'appearing',
#  ',',
#  'these',
#  'extracts',
#  'are',
#  'solely',
#  'valuable',
#  'or',
#  'entertaining',
#  ',',
#  'as',
#  'affording',
#  'a',
#  'glancing',
#  'bird',
#  "'",
#  's',
#  'eye',
#  'view',
#  'of',
#  'what',
#  'has',
#  'been',
#  'promiscuously',
#  'said',
#  ',',
#  'thought',
#  ',',
#  'fancied',
#  ',',
#  'and',
#  'sung',
#  'of',
#  'Leviathan',
#  ',',
#  'by',
#  'many',
#  'nations',
#  'and',
#  'generations',
#  ',',
#  'including',
#  'our',
#  'own',
#  '.',
#  'So',
#  'fare',
#  'thee',
#  'well',
#  ',',
#  'poor',
#  'devil',
#  'of',
#  'a',
#  'Sub',
#  '-',
#  'Sub',
#  ',',
#  'whose',
#  'commentator',
#  'I',
#  'am',
#  '.',
#  'Thou',
#  'belongest',
#  'to',
#  'that',
#  'hopeless',
#  ',',
#  'sallow',
#  'tribe',
#  'which',
#  'no',
#  'wine',
#  'of',
#  'this',
#  'world',
#  'will',
#  'ever',
#  'warm',
#  ';',
#  'and',
#  'for',
#  'whom',
#  'even',
#  'Pale',
#  'Sherry',
#  'would',
#  'be',
#  'too',
#  'rosy',
#  '-',
#  'strong',
#  ';',
#  'but',
#  'with',
#  'whom',
#  'one',
#  'sometimes',
#  'loves',
#  'to',
#  'sit',
#  ',',
#  'and',
#  'feel',
#  'poor',
#  '-',
#  'devilish',
#  ',',
#  'too',
#  ';',
#  'and',
#  'grow',
#  'convivial',
#  'upon',
#  'tears',
#  ';',
#  'and',
#  'say',
#  'to',
#  'them',
#  'bluntly',
#  ',',
#  'with',
#  'full',
#  'eyes',
#  'and',
#  'empty',
#  'glasses',
#  ',',
#  'and',
#  'in',
#  'not',
#  'altogether',
#  'unpleasant',
#  'sadness',
#  '--',
#  'Give',
#  'it',
#  'up',
#  ',',
#  'Sub',
#  '-',
#  'Subs',
#  '!',
#  'For',
#  'by',
#  'how',
#  'much',
#  'the',
#  'more',
#  'pains',
#  'ye',
#  'take',
#  'to',
#  'please',
#  'the',
#  'world',
#  ',',
#  'by',
#  'so',
#  'much',
#  'the',
#  'more',
#  'shall',
#  'ye',
#  'for',
#  'ever',
#  'go',
#  'thankless',
#  '!',
#  'Would',
#  'that',
#  'I',
#  'could',
#  'clear',
#  'out',
#  'Hampton',
#  'Court',
#  'and',
#  'the',
#  'Tuileries',
#  'for',
#  'ye',
#  '!',
#  'But',
#  'gulp',
#  'down',
#  'your',
#  'tears',
#  'and',
#  'hie',
#  'aloft',
#  'to',
#  'the',
#  'royal',
#  '-',
#  'mast',
#  'with',
#  'your',
#  'hearts',
#  ';',
#  'for',
#  'your',
#  'friends',
#  'who',
#  'have',
#  'gone',
#  'before',
#  'are',
#  'clearing',
#  'out',
#  'the',
#  'seven',
#  '-',
#  'storied',
#  'heavens',
#  ',',
#  'and',
#  'making',
#  'refugees',
#  'of',
#  'long',
#  '-',
#  'pampered',
#  'Gabriel',
#  ',',
#  'Michael',
#  ',',
#  'and',
#  'Raphael',
#  ',',
#  'against',
#  'your',
#  'coming',
#  '.',
#  'Here',
#  'ye',
#  'strike',
#  'but',
#  'splintered',
#  'hearts',
#  'together',
#  '--',
#  'there',
#  ',',
#  'ye',
#  'shall',
#  'strike',
#  'unsplinterable',
#  'glasses',
#  '!',
#  'EXTRACTS',
#  '.',
#  '"',
#  'And',
#  'God',
#  'created',
#  'great',
#  'whales',
#  '."',
#  '--',
#  'GENESIS',
#  '.',
#  '"',
#  'Leviathan',
#  'maketh',
#  'a',
#  'path',
#  'to',
#  'shine',
#  'after',
#  'him',
#  ';',
#  'One',
#  'would',
#  'think',
#  'the',
#  'deep',
#  'to',
#  'be',
#  'hoary',
#  '."',
#  '--',
#  'JOB',
#  '.',
#  '"',
#  'Now',
#  'the',
#  'Lord',
#  'had',
#  'prepared',
#  'a',
#  'great',
#  'fish',
#  'to',
#  'swallow',
#  'up',
#  'Jonah',
#  '."',
#  '--',
#  'JONAH',
#  '.',
#  '"',
#  'There',
#  'go',
#  'the',
#  'ships',
#  ';',
#  'there',
#  'is',
#  'that',
#  'Leviathan',
#  'whom',
#  'thou',
#  'hast',
#  'made',
#  'to',
#  'play',
#  'therein',
#  '."',
#  '--',
#  'PSALMS',
#  '.',
#  '"',
#  'In',
#  'that',
#  'day',
#  ',',
#  'the',
#  'Lord',
#  'with',
#  'his',
#  'sore',
#  ',',
#  'and',
#  'great',
#  ',',
#  'and',
#  'strong',
#  'sword',
#  ',',
#  'shall',
#  'punish',
#  'Leviathan',
#  'the',
#  'piercing',
#  'serpent',
#  ',',
#  'even',
#  'Leviathan',
#  'that',
#  'crooked',
#  'serpent',
#  ';',
#  'and',
#  'he',
#  'shall',
#  'slay',
#  'the',
#  'dragon',
#  'that',
#  'is',
#  'in',
#  'the',
#  'sea',
#  '."',
#  '--',
#  'ISAIAH',
#  '"',
#  'And',
#  'what',
#  'thing',
#  'soever',
#  'besides',
#  'cometh',
#  'within',
#  'the',
#  'chaos',
#  'of',
#  'this',
#  'monster',
#  "'",
#  's',
#  'mouth',
#  ',',
#  'be',
#  'it',
#  'beast',
#  ',',
#  'boat',
#  ',',
#  'or',
#  'stone',
#  ',',
#  'down',
#  'it',
#  'goes',
#  'all',
#  'incontinently',
#  'that',
#  'foul',
#  'great',
#  'swallow',
#  'of',
#  'his',
#  ',',
#  'and',
#  'perisheth',
#  'in',
#  'the',
#  'bottomless',
#  'gulf',
#  'of',
#  'his',
#  'paunch',
#  '."',
#  '--',
#  'HOLLAND',
#  "'",
#  'S',
#  'PLUTARCH',
#  "'",
#  'S',
#  'MORALS',
#  '.',
#  '"',
#  'The',
#  'Indian',
#  'Sea',
#  'breedeth',
#  'the',
#  'most',
#  'and',
#  'the',
#  'biggest',
#  'fishes',
#  'that',
#  'are',
#  ':',
#  'among',
#  'which',
#  'the',
#  'Whales',
#  'and',
#  'Whirlpooles',
#  'called',
#  'Balaene',
#  ',',
#  'take',
#  'up',
#  'as',
#  'much',
#  'in',
#  'length',
#  'as',
#  'four',
#  'acres',
#  'or',
#  'arpens',
#  'of',
#  'land',
#  '."',
#  '--',
#  'HOLLAND',
#  "'",
#  'S',
#  'PLINY',
#  '.',
#  '"',
#  'Scarcely',
#  'had',
#  'we',
#  'proceeded',
#  'two',
#  'days',
#  'on',
#  'the',
#  'sea',
#  ',',
#  'when',
#  'about',
#  'sunrise',
#  'a',
#  'great',
#  'many',
#  'Whales',
#  'and',
#  'other',
#  'monsters',
#  'of',
#  'the',
#  'sea',
#  ',',
#  'appeared',
#  '.',
#  'Among',
#  'the',
#  'former',
#  ',',
#  'one',
#  'was',
#  'of',
#  'a',
#  'most',
#  'monstrous',
#  'size',
#  '.',
#  '...',
#  'This',
#  'came',
#  'towards',
#  'us',
#  ',',
#  'open',
#  '-',
#  'mouthed',
#  ',',
#  'raising',
#  'the',
#  'waves',
#  'on',
#  'all',
#  'sides',
#  ',',
#  'and',
#  'beating',
#  'the',
#  'sea',
#  'before',
#  'him',
#  'into',
#  'a',
#  'foam',
#  '."',
#  '--',
#  'TOOKE',
#  "'",
#  'S',
#  'LUCIAN',
#  '.',
#  '"',
#  'THE',
#  'TRUE',
#  'HISTORY',
#  '."',
#  '"',
#  'He',
#  'visited',
#  'this',
#  'country',
#  'also',
#  'with',
#  'a',
#  'view',
#  'of',
#  'catching',
#  'horse',
#  '-',
#  'whales',
#  ',',
#  'which',
#  'had',
#  'bones',
#  'of',
#  'very',
#  'great',
#  'value',
#  'for',
#  'their',
#  'teeth',
#  ',',
#  'of',
#  'which',
#  'he',
#  'brought',
#  'some',
#  'to',
#  'the',
#  'king',
#  '.',
#  '...',
#  'The',
#  'best',
#  'whales',
#  'were',
#  'catched',
#  'in',
#  'his',
#  'own',
#  'country',
#  ',',
#  'of',
#  'which',
#  'some',
#  'were',
#  'forty',
#  '-',
#  'eight',
#  ',',
#  'some',
#  'fifty',
#  'yards',
#  'long',
#  '.',
#  'He',
#  ...]

# %%
# 중복 단어 제거 후 나열하기 (`set`이 중복 불가능함을 이용)
print(set(moby.tokens))
# Out:
# {'Icy', 'collar', '101', 'Church', 'officer', 'Consider', 'diabolism', 'mout', 'buttoned', 'wondrously', 'smothering', 'untrackably', 'flints', 'certain', 'meddling', 'untimely', 'genial', 'pagoda', 'mob', 'absolute', 'oil', 'carriages', 'favoured', 'pyres', 'behead', 'proverbial', 'commenting', 'scornfully', 'handedness', 'yonder', 'vacancies', 'pocketing', 'blade', 'g', 'grenadier', 'HISTORY', 'ticklish', 'Slid', 'Dauphine', 'Nature', 'staved', 'blasting', 'THUS', 'ball', 'scrupulously', 'Long', 'desperate', 'pleases', 'catacombs', 'improvement', 'Yale', 'patentees', 'reefing', 'knockers', 'trampling', 'wonderful', 'centuries', 'condense', 'Be', 'Justinian', 'appal', 'Slowly', 'pans', 'clove', 'solicited', 'stagnant', 'suspect', 'electric', 'buoy', 'Horn', 'warmer', 'tuns', 'BELFAST', 'personality', 'enrolled', 'burstingly', 'attest', 'monumental', 'correspond', 'ant', 'cheered', 'quantity', 'Heed', 'perilousness', 'aesthetically', 'curing', 'PRESIDENCY', 'exchange', 'frequency', 'Bally', 'stunsails', 'illustrate', 'analogies', 'plague', 'Sammy', 'gashed', 'curtains', 'succeeds', 'mown', 'howl', 'rides', 'perish', 'lodgings', 'mantle', 'Vermont', 'excited', 'retains', 'Rodmond', 'undiscovered', 'Tunnels', 'SACRED', 'points', 'Ego', 'savory', 'peculiar', 'worshipping', 'apprehensiveness', 'incarnated', 'sided', 'perceiving', 'attestation', 'slantingly', 'hummed', 'figures', 'shunning', 'unrecking', 'enclosed', 'hundredth', 'imaginary', 'puddingers', 'occupied', 'enjoy', 'Cuba', 'greeted', 'rightly', 'Dunder', 'examined', 'packet', 'defile', 'astonished', 'brushwood', 'REPUBLICA', 'bipeds', 'transferred', 'angles', 'Satan', 'region', 'Anyhow', 'Tashtego', 'Champollion', 'levers', 'journeys', 'tedious', 'Clam', 'listened', 'baronial', 'God', 'Frenchmen', 'odd', '---,', 'Believe', 'pleased', 'number', 'firma', 'laureate', 'goadings', 'Massacre', 'piling', 'terms', 'picking', 'viewed', 'tying', 'relying', 'happens', 'Wrapping', 'distortions', 'uncleanliness', 'make', 'Haul', 'tucks', 'deploy', 'honourable', 'toils', 'shortened', 'gloomiest', 'aerated', '82', 'Once', 'troubledly', 'eggs', 'Lents', 'awaken', 'OUT', 'cheating', 'deadliness', 'incommodiously', 'passports', 'boobies', 'prescription', 'Iceberg', 'seizing', 'tetering', 'smiled', 'scorched', 'gross', 'shown', 'grains', 'aloud', 'tug', 'road', 'elements', 'drawing', 'trumpet', 'Almost', 'gleamed', 'repulses', 'unappeasable', 'Spermaceti', 'foam', 'rock', 'aye', 'sinks', 'skimming', 'notes', 'chamber', 'overmuch', 'Diminish', 'clergy', 'warningly', 'unthinkingly', 'ascribable', 'teetering', 'purely', 'hoof', 'officio', 'HARD', 'lonesomeness', 'Dante', 'si', 'unite', 'crouching', 'uncounted', 'sandpaper', 'dissemble', 'veneration', 'vines', 'eastward', 'ever', 'vacating', 'compendious', 'Rome', 'Ehrenbreitstein', 'Lashed', 'embarking', 'Benjamin', 'distant', 'Seneca', 'FISHERMAN', 'facetiousness', 'popular', 'hurt', 'decay', 'explanation', 'clusters', 'Acushnet', 'going', 'COILS', 'punctilious', 'county', 'clews', 'perfect', 'membranes', 'meadows', 'spin', 'wailing', 'agreeable', 'Welding', 'hamlets', 'Being', 'Interweaving', 'spied', 'paunch', 'ropeyarn', 'sighting', 'tool', 'robust', 'ring', 'crystals', 'bliss', 'recoil', 'uneventfulness', 'Hindoo', 'ME', 'guinea', 'works', 'morn', 'roofed', 'Postscript', 'tinkling', 'streamers', 'unmixed', 'pines', 'trivial', 'abandon', '500', 'bone', 'tears', 'longer', 'lad', 'darts', 'Extending', 'daunted', 'imperfectly', 'thro', 'drunk', 'mightier', 'Talk', 'splashed', 'undetected', 'dip', 'motions', 'sublimity', 'dollars', 'tidings', 'discovering', 'Arkansas', 'concrete', 'Rib', 'canals', 'model', 'cohorts', 'frigates', 'squared', 'SOMETHING', 'roof', 'triangles', 'villainies', 'undecreasing', 'ordinarily', 'fate', 'strain', 'sheaths', 'forgive', 'Gros', 'leaving', 'unfort', 'springing', 'slips', 'won', 'lie', 'storied', 'presented', 'gout', 'individually', 'crowning', 'stowed', 'LINE', 'musked', 'Cousin', 'melt', 'Ahasuerus', 'trio' ...

# %%
# 오름차순 정렬하기
print(sorted(set(moby.tokens)))
# Out:
# ['!', '!"', '!"--', "!'", '!\'"', '!)', '!)"', '!*', '!--', '!--"', "!--'", '"', '"\'', '"--', '"...', '";', '$', '&', "'", "',", "',--", "'-", "'--", "';", '(', ')', '),', ')--', ').', ').--', '):', ');', ');--', '*', ',', ',"', ',"--', ",'", ",'--", ',)', ',*', ',--', ',--"', ",--'", '-', '--', '--"', "--'", '--\'"', '--(', '---"', '---,', '.', '."', '."*', '."--', ".'", '.\'"', '.)', '.*', '.*--', '.,', '.--', '.--"', '...', '....', '.]', '000', '1', '10', '100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '11', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '12', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '13', '130', '131', '132', '133', '134', '135', '14', '144', '1492', '15', '150', '15th', '16', '1652', '1668', '1671', '1690', '1695', '16th', '17', '1726', '1729', '1750', '1772', '1775', '1776', '1778', '1779', '1788', '1791', '1793', '18', '180', '1807', '1819', '1820', '1821', '1825', '1828', '1833', '1836', '1839', '1840', '1842', '1846', '1850', '1851', '19', '1ST', '1st', '2', '20', '2000', '200th', '21', '21st', '22', '23', '24', '25', '26', '27', '275th', '28', '29', '2ND', '3', '30', '31', '31st', '32', '33', '34', '35', '36', '37', '38', '39', '3D', '3d', '4', '40', '400', '41', '42', '43', '44', '440', '45', '46', '47', '48', '49', '4TH', '5', '50', '500', '51', '52', '53', '54', '55', '550', '56', '57', '58', '59', '5TH', '6', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '7', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '8', '80', '800', '81', '82', '83', '84', '85', '86', '87', '88', '89', '890', '9', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99', ':', ':"-', ':--', ':--"', ":--'", ';', ';"', ';"--', ';"--(', ";'", ';*', ';--', ';--"', ";--'", '?', '?"', '?"--', "?'", "?'--'", '?--', '?--"', "?--'", 'A', 'ABOUT', 'ACCOUNT', 'ADDITIONAL', 'ADVANCING', 'ADVENTURES', 'AFFGHANISTAN', 'AFRICA', 'AFTER', 'AGAINST', 'AHAB', 'ALFRED', 'ALGERINE', 'ALIVE', 'ALL', 'ALONE', 'AM', 'AMERICA', 'AMONG', 'ANCHORS', 'AND', 'ANGLO', 'ANIMAL', 'ANNALS', 'ANNUS', 'ANOTHER', 'ANY', 'APOLOGY', 'APPLICATION', 'APPROACHING', 'ARCTIC', 'ARE', 'AROUND', 'AS', 'ASCENDING', 'ASIA', 'ASIDE', 'ASPECT', 'AT', 'ATTACK', 'ATTACKED', 'ATTITUDES', 'AUGUST', 'AUTHOR', 'AZORE', 'Abashed', 'Abednego', 'Abel', 'Abjectus', 'Aboard', 'Abominable', 'About', 'Above', 'Abraham', 'Academy', 'Accessory', 'According', 'Accordingly', 'Accursed', 'Achilles', 'Actium', 'Acushnet', 'Adam', 'Adieu', 'Adios', 'Admiral', 'Admirals', 'Advance', 'Advancement', 'Adventures', 'Adverse', 'Advocate', 'Affected', 'Affidavit', 'Affrighted', 'Afric', 'Africa', 'African', 'Africans', 'Aft', 'After', 'Afterwards', 'Again', 'Against', 'Agassiz', 'Ages', 'Ah', 'Ahab', 'Ahabs', 'Ahasuerus', 'Ahaz', 'Ahoy', 'Ain', 'Air', 'Akin', 'Alabama', 'Aladdin', 'Alarmed', 'Alas', 'Albatross', 'Albemarle', 'Albert', 'Albicore', 'Albino', 'Aldrovandi', 'Aldrovandus', 'Alexander', 'Alexanders', 'Alfred', 'Algerine', 'Algiers', 'Alike', 'Alive', 'All', 'Alleghanian', 'Alleghanies', 'Alley', 'Almanack', 'Almighty', 'Almost', 'Aloft', 'Alone', 'Alps', 'Already', 'Also', 'Am', 'Ambergriese', 'Ambergris', 'Amelia', 'America', 'American', 'Americans', 'Americas', 'Amittai', 'Among', 'Amsterdam', 'An', 'Anacharsis', 'Anak', 'Anatomist', 'And', 'Andes', 'Andrew', 'Andromeda', 'Angel', 'Angelo', 'Angels', 'Animated', 'Annawon', 'Anne', 'Anno', 'Anomalous', 'Another', 'Answer', 'Antarctic', 'Antilles', 'Antiochus', 'Antony', 'Antwerp', 'Anvil', 'Any', 'Anyhow', 'Anything', 'Anyway', 'Apollo', 'Apoplexy', 'Applied', 'Apply', 'April', 'Aquarius', 'Arch', 'Archbishop', 'Arched', 'Archer', 'Archipelagoes', 'Archy', 'Arctic', 'Are', 'Arethusa', 'Argo', 'Aries', 'Arion', 'Aristotle', 'Ark', 'Arkansas', 'Arkite', 'Arm', 'Armada', 'Arnold', 'Aroostook', 'Around', 'Arrayed', 'Arrived', 'Arsacidean', 'Arsacides', 'Art', 'Artedi', 'Arter', 'Articles', 'As', 'Asa', 'Ashantee', 'Ashore', 'Asia', 'Asia ...

# %%
# 내림차순 정렬하기
print(sorted(set(moby.tokens), reverse=True))
# Out:
# ['zoology', 'zones', 'zoned', 'zone', 'zodiac', 'zig', 'zephyr', 'zeal', 'zay', 'zag', 'youthful', 'youth', 'yourselves', 'yourself', 'yourselbs', 'yours', 'your', 'youngish', 'youngest', 'younger', 'young', 'you', 'yore', 'yonder', 'yon', 'yoking', 'yokes', 'yoked', 'yoke', 'yields', 'yielding', 'yielded', 'yield', 'yet', 'yesterday', 'yes', 'yells', 'yellowish', 'yellow', 'yelling', 'yelled', 'yell', 'yeast', 'years', 'yearly', 'year', 'yea', 'ye', 'yawning', 'yawned', 'yawingly', 'yawing', 'yawed', 'yaw', 'yarns', 'yarn', 'yards', 'yard', 'y', 'wrung', 'wrought', 'wrote', 'wrong', 'written', 'writing', 'writhing', 'writhed', 'writers', 'writer', 'write', 'writ', 'wrists', 'wrist', 'wrinkling', 'wrinkles', 'wrinkled', 'wring', 'wriggling', 'wriggles', 'wretchedly', 'wretched', 'wrestlings', 'wrestling', 'wrest', 'wrenching', 'wrenched', 'wrench', 'wrecks', 'wrecked', 'wreck', 'wreath', 'wreak', 'wrath', 'wrapt', 'wraps', 'wrapping', 'wrapper', 'wrapped', 'wrapall', 'wrap', 'wrangling', 'woven', 'wounds', 'wounding', 'wounded', 'wound', 'wouldst', 'wouldn', 'would', 'worthy', 'worth', 'worsted', 'worst', 'worships', 'worshipping', 'worshippers', 'worshipper', 'worshipped', 'worship', 'worse', 'worryings', 'worried', 'worn', 'worming', 'worm', 'worlds', 'worldly', 'world', 'works', 'workmen', 'workmanlike', 'workman', 'working', 'workers', 'worker', 'worked', 'work', 'wore', 'words', 'wordless', 'word', 'woraciousness', 'woracious', 'woollen', 'wool', 'wooing', 'woof', 'woody', 'woods', 'woodpecker', 'woodlands', 'woodland', 'wooden', 'wooded', 'woodcock', 'wood', 'wonted', 'wont', 'wonst', 'wondrousness', 'wondrously', 'wondrous', 'wonders', 'wonderments', 'wonderment', 'wonderingly', 'wondering', 'wonderfulness', 'wonderfully', 'wonderful', 'wondered', 'wonder', 'won', 'women', 'womb', 'woman', 'wolves', 'wolfish', 'woes', 'woeful', 'woe', 'wives', 'wived', 'witty', 'wittiness', 'witted', 'wits', 'witnessing', 'witnesses', 'witness', 'withstanding', 'withstand', 'without', 'within', 'withholding', 'withhold', 'withered', 'withdrew', 'withdraws', 'withdrawn', 'withdrawing', 'withdrawals', 'withdrawal', 'withdraw', 'withal', 'with', 'witchery', 'witcheries', 'witch', 'wit', 'wished', 'wish', 'wisest', 'wisely', 'wiseish', 'wise', 'wisdom', 'wires', 'wire', 'wiping', 'wipe', 'wintry', 'winter', 'winsome', 'winks', 'winking', 'wink', 'wings', 'winged', 'wing', 'wines', 'wine', 'windy', 'windward', 'winds', 'windrowed', 'windpipe', 'windows', 'window', 'windlass', 'winding', 'windbound', 'wind', 'wincing', 'winces', 'wilted', 'wilt', 'wills', 'willow', 'willingness', 'willingly', 'willing', 'willed', 'willains', 'will', 'wilfulness', 'wilful', 'wilds', 'wildness', 'wildly', 'wildest', 'wilderness', 'wild', 'wigwams', 'wigwam', 'wights', 'wight', 'wife', 'wields', 'wielded', 'width', 'widows', 'widowed', 'widow', 'widest', 'widening', 'widely', 'wide', 'wid', 'wickedness', 'wicked', 'wick', 'why', 'whosoever', 'whose', 'whooping', 'whoop', 'whom', 'wholly', 'wholesome', 'whole', 'whoever', 'who', 'whizzings', 'whittling', 'whittled', 'whitish', 'whither', 'whitewashed', 'whitest', 'whites', 'whitenesses', 'whiteness', 'whitened', 'white', 'whit', 'whistlingly', 'whistling', 'whistled', 'whistle', 'whist', 'whispers', 'whisperingly', 'whispering', 'whispered', 'whisper', 'whiskey', 'whiskers', 'whisker', 'whirlwinds', 'whirls', 'whirlpool', 'whirling', 'whirled', 'whirl', 'whips', 'whipping', 'whipped', 'whip', 'whimsiness', 'whimsicalities', 'whim', 'while', 'whiffs', 'whiff', 'whichever', 'which', 'whew', 'whetstones', 'whetstone', 'whets', 'whether', 'wherewith', 'wherever', 'whereupon', 'whereto', 'wheresoe', 'whereon', 'whereof', 'wherein', 'wherefore', 'whereby', 'whereat', 'whereas', 'where', 'whenever', 'whencesoe', 'whence', 'when', 'whelmings', 'whelmed', 'whelm', 'wheezing', 'wheels', 'wheeling', 'wheeled', 'wheelbarrow', 'wheel', 'wheat', 'whatsoever', 'whatever', 'what', 'wharves', 'wharf', 'whang', 'whaling', 'whalin' ...

# %%
# 내림차순 정렬 후 상위 10개만 추출하기
print(sorted(set(moby.tokens), reverse=True)[:10])
# Out:
# ['zoology', 'zones', 'zoned', 'zone', 'zodiac', 'zig', 'zephyr', 'zeal', 'zay', 'zag']

# %%
# 총 길이 구하기
print(len(moby.tokens))

# 중복 제거한 총 길이 구하기
print(len(set(moby.tokens)))
# Out:
# 260819
# 19317

# %%
# lexical diversity(어휘의 다양성) 구하기
print(len(set(moby.tokens)) / len(moby.tokens))
# Out:
# 0.07406285585022564

# %% [markdown]
# ## Quiz 1.
# - text9에서 lexical diversity 계산하기
# - text6에서 중복없이 내림차순 정렬하기
#     - a. 앞에서 단어 10개 추출하기
#     - b. 'z'가 있으면 대문자로 바꾸기, 'z'가 없는데 4자 이상이면 끝 글자 대문자로 바꾸기 (조건문 연습)

# %%
# !pip install nltk
import nltk
nltk.download('book', quiet=True)
from nltk import book
# Out:
# Requirement already satisfied: nltk in c:\anaconda3\lib\site-packages (3.6.5)
# Requirement already satisfied: click in c:\anaconda3\lib\site-packages (from nltk) (8.0.3)
# Requirement already satisfied: joblib in c:\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\anaconda3\lib\site-packages (from nltk) (2021.8.3)
# Requirement already satisfied: tqdm in c:\anaconda3\lib\site-packages (from nltk) (4.62.3)
# Requirement already satisfied: colorama in c:\users\bingo\appdata\roaming\python\python39\site-packages (from click->nltk) (0.4.4)

# %%
# Quiz 1-1
text9 = book.text9
text9.tokens

print(len(set(text9.tokens)) / len(text9.tokens))
# Out:
# 0.0983485761345412

# %%
# Quiz 1-2
text6 = book.text6
text6.tokens

# a
print(sorted(set(text6.tokens), reverse=True)[:10])

# b
text6_rev_top10 = sorted(set(text6.tokens), reverse=True)[:10]

for i in text6_rev_top10:
    if 'z' in i:
        print(i.replace('z', 'Z'))
    elif ('z' not in i) and (len(i) >= 4):
        print(i.replace(i[-1:], i[-1:].upper()))
# Out:
# ['zoosh', 'zoop', 'zoo', 'zone', 'zhiv', 'yourself', 'yours', 'your', 'young', 'you']
# Zoosh
# Zoop
# Zoo
# Zone
# Zhiv
# yourselF
# yourS
# youR
# younG

# %% [markdown]
# ## Quiz 2.
# - 입력: 주민등록번호, 휴대폰번호, 이메일
#     - 주민번호, 휴대폰번호는 숫자만 입력 (`-` 없이)
#     - 이메일은 아이디만 입력 ('@의 뒷부분' 없이)
# - 출력:
#     - "당신은 {}년 {}월 {}일 출생의 {남성/여성}입니다."
#     - 휴대폰번호: {}
#         - 하이픈으로 연결하기
#     - 이메일: {아이디}@gmail.com

# %%
id_number = str(input('주민등록번호를 입력하세요(하이픈 제외): '))
phone_number = str(input('휴대폰번호를 입력하세요(하이픈 제외): '))
email = str(input('이메일을 입력하세요(도메인 제외): '))
# Out:
# 주민등록번호를 입력하세요(하이픈 제외):  0206173000000
# 휴대폰번호를 입력하세요(하이픈 제외):  01012341234
# 이메일을 입력하세요(도메인 제외):  hufs1954

# %%
if (id_number[6:7] == '1') or (id_number[6:7] == '3'):
    gender = '남성'
else: gender = '여성'

if id_number[6:7] == '1':
    birth_year = int('19'+id_number[:2])
else: birth_year = int('20'+id_number[:2])

birth_month = int(id_number[2:4])
birth_day = int(id_number[4:6])

print(f"당신은 {birth_year}년 {birth_month}월 {birth_day}일 출생의 {gender}입니다.")
# Out:
# 당신은 2002년 6월 17일 출생의 남성입니다.

# %%
phone_number_hyphen = phone_number[:3]+'-'+phone_number[3:7]+'-'+phone_number[7:11]
print(f'휴대폰 번호: {phone_number_hyphen}')
# Out:
# 휴대폰 번호: 010-1234-1234

# %%
print(f'이메일: {email}@gmail.com')
# Out:
# 이메일: hufs1954@gmail.com
